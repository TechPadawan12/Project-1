# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json

# %%
salaries_1985to2018_data = "salaries_1985to2018.csv"
Season_stats_data
salaries_1985to2018_data_df = pd.read_csv(salaries_1985to2018_data)
salaries_1985to2018_data_df
# Out:
#       league  player_id    salary   season  season_end  season_start  \
# 0        NBA  abdelal01    395000  1990-91        1991          1990
# 1        NBA  abdelal01    494000  1991-92        1992          1991
# 2        NBA  abdelal01    500000  1992-93        1993          1992
# 3        NBA  abdelal01    805000  1993-94        1994          1993
# 4        NBA  abdelal01    650000  1994-95        1995          1994
# 5        NBA  abdulka01   1530000  1984-85        1985          1984
# 6        NBA  abdulka01   2030000  1985-86        1986          1985
# 7        NBA  abdulka01   2000000  1987-88        1988          1987
# 8        NBA  abdulka01   3000000  1988-89        1989          1988
# 9        NBA  abdulma02   1660000  1990-91        1991          1990
# 10       NBA  abdulma02   2008000  1991-92        1992          1991
# 11       NBA  abdulma02   2358000  1992-93        1993          1992
# 12       NBA  abdulma02   1825000  1993-94        1994          1993
# ...

# %%
#remove all spaces front of variable and aft of variable
salaries_1985to2018_data_df.columns.str.replace(' ', '')
salaries_1985to2018_data_df
# Out:
#       league  player_id    salary   season  season_end  season_start  \
# 0        NBA  abdelal01    395000  1990-91        1991          1990
# 1        NBA  abdelal01    494000  1991-92        1992          1991
# 2        NBA  abdelal01    500000  1992-93        1993          1992
# 3        NBA  abdelal01    805000  1993-94        1994          1993
# 4        NBA  abdelal01    650000  1994-95        1995          1994
# 5        NBA  abdulka01   1530000  1984-85        1985          1984
# 6        NBA  abdulka01   2030000  1985-86        1986          1985
# 7        NBA  abdulka01   2000000  1987-88        1988          1987
# 8        NBA  abdulka01   3000000  1988-89        1989          1988
# 9        NBA  abdulma02   1660000  1990-91        1991          1990
# 10       NBA  abdulma02   2008000  1991-92        1992          1991
# 11       NBA  abdulma02   2358000  1992-93        1993          1992
# 12       NBA  abdulma02   1825000  1993-94        1994          1993
# ...

# %%
salaries_1985to2018_data_df['salary'] = salaries_1985to2018_data_df['salary'].astype(float)
salaries_1985to2018_data_df
# Out:
#       league  player_id      salary   season  season_end  season_start  \
# 0        NBA  abdelal01    395000.0  1990-91        1991          1990
# 1        NBA  abdelal01    494000.0  1991-92        1992          1991
# 2        NBA  abdelal01    500000.0  1992-93        1993          1992
# 3        NBA  abdelal01    805000.0  1993-94        1994          1993
# 4        NBA  abdelal01    650000.0  1994-95        1995          1994
# 5        NBA  abdulka01   1530000.0  1984-85        1985          1984
# 6        NBA  abdulka01   2030000.0  1985-86        1986          1985
# 7        NBA  abdulka01   2000000.0  1987-88        1988          1987
# 8        NBA  abdulka01   3000000.0  1988-89        1989          1988
# 9        NBA  abdulma02   1660000.0  1990-91        1991          1990
# 10       NBA  abdulma02   2008000.0  1991-92        1992          1991
# 11       NBA  abdulma02   2358000.0  1992-93        1993          1992
# ...

# %%
salaries_1985to2018_data_df
